# %% [markdown]
# <a href="https://colab.research.google.com/github/32KimJunGu/ai/blob/main/Algorithm1(day5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1. 알고리즘이란....
- 문제나 과제를 해결하기 위한 처리절차를 구체적인 순서로 표현한 아이디어 또는 생각]
- 알고리즘 자체는 일상생활에서도 많이 이미 사용하고 있다.
- 요리의 레시피, 음악의 악보, 가전제품 사용설명서 등
- 문자, 기호, 일러스트 등으로 나타낸다.

2. 알고리즘과 프로그램
- 알고리즘을 프로그래밍 언어로 기술하면 프로그램이 된다.
- 프로그래밍 언어(파이썬, 자바, 씨 ....)는 컴퓨터에 지시하기위한 인공 언어이다.

3. 프로그램 작성에서의 알고리즘
- 프로그램 작성은 기획, 설계(*) , 프로그래밍, 디버그로 진행한다
- 알고리즘은 설계 단계에서 필요하다.

4. 좋은 알고리즘이란 ?
- 알기 쉽다. (쉬운 이해)
- 속도가 빠르다. 
- 효율적이다. (메모리를 작게 사용한다.)
- 재이용(범용성)이 쉽다.(객체지향프로그래밍)

5. 왜 알고리즘을 공부해야 하나
- 좋은 프로그램을 만들기 위해 ( 빠르고, 효율적, 범용성)
- 프로그램의 좋고 나쁨을 판단하기 위해
- 프로그램 작성 과정 전체를 효율화하기 위해
- 프로그램 기술을 향상시키기 위해

6. 알고리즘의 조건
- 정확한 결과를 얻을 수 있어야 한다.
  ( 알고리즘은 문제나 과제를 해결하기 위한 절차)
- 반드시 종료가 되어야 한다.
  (중간처리나 절차가 잘못 만들어지면 영원히 끝나지 않는다.)

7. 알고리즘의 기본형 3가지
- 순차 구조 : 처음부터 순서대로 처리하는 절차
  예) 심부름
  1 슈퍼마켓에 간다.
  2 라면을 산다
  3 집으로 돌아온다.
  실행을 원하는 처리를 위로부터 순서대로 작성한다.
  알고리즘 중에서도 가장 많이 사용된다.

- 선택 구조 : 조건식으로 판단해 실행할 절차를 전환하는 구조

- 반복 구조 : 조건을 만족하는 동안 같은 처리를 반복하는 절차

# %% [markdown]
# ![순차선택반복1.jpg](data:image/jpeg;base64,...)

# %%
# 의사 코드 pseudo code

1. 순차구조
  - 슈퍼마켓에 간다.
  - 라면을 산다.
  - 집으로 돌아온다.

2. 선택구조
  - 슈퍼마켓에 간다.
  - 라면이 있나?
    라면을 산다
    ------------
    떡을 산다
  - 집으로 돌아온다.

3. 반복구조
  - 슈퍼마켓에 간다.
  - 라면이 있나?
    라면을 산다
    ------------
    떡을 산다
  
  거스름 돈이 500원 보다 많다.
    - 붕어빵을 산다.


  - 집으로 돌아온다.

# %%
#1 삼각형의 면적을 계산하는 알고리즘

삼각형의 면적 = 밑변 * 높이 / 2

의사코드로 작성

- 밑변과 높이를 입력
- area <- base * height / 2
- area 출력

# %% [markdown]
# ![순서도_기본.jpg](data:image/jpeg;base64,...)

# %%
base = int(input('base : '))
height = int(input('height : '))

area = base * height / 2

print(area)
# Out:
# base : 2
# height : 3
# 3.0

# %%
#2 두 데이터의 대소를 판단하는 알고리즘

의사코드

- a와 b를 입력한다.
- a<b
  a출력
    a = b
    a와 b는 같다 출력
    ---------------
    b를 출력

# %%
##############################################################################
# Function
##############################################################################

# 함수 만들기


# 수학에서의 함수와 유사

# 딸기(input) - > 믹서기(함수) -> 딸기 주스(output)
# 바나나(input) - > 믹서기(함수) -> 바나나 주스(output)
# 사과(input) - > 믹서기(함수) -> 사과 주스(output)


#함수의 가장 기본형

def 함수명(input) :
  # 수행

# %%
def print_3(val):
  print(val)
  print(val)
  print(val)

print_3('hi')
# Out:
# hi
# hi
# hi

# %%
# def print_3(val, n):
#   print(val)
#   print(val)
#   print(val)

# print_3('hello',5)


def print_3(val, n):
  for i in range(n):
    print(val)

print_3('hello',5)
# Out:
# hello
# hello
# hello
# hello
# hello

# %%
# ,매개 변수를 2개 지정했으나 함수를 호출할때 1개만 넣으면 에러가 발생한다.

def print_3(val, n):
  for i in range(n):
    print(val)

print_3('hi')

# %%
# ,매개 변수를 2개 지정했으나 함수를 호출할때 3개를 넣으면 에러가 발생한다.

def print_3(val, n):
  for i in range(n):
    print(val)

print_3('hi',2,3)

# %%
# 가변 매개 변수
# 함수를 선언할 때 매개변수와 함수를 호출할 때 매개변수가 같아야만 했다.적어도 안되고 많아도 안된다.

def print_n_times(n, *val):           #val은 변수이므로 마음대로 이름을 바꿔도 됨
  for i in range(n):
    for v in val:
      print(v)
    print()

print_n_times(3,'hi','hello','good morning')
print_n_times(3,'hi','hello')
# Out:
# hi
# hello
# good morning
#
# hi
# hello
# good morning
#
# hi
# hello
# good morning
#
# hi
# hello
#
# hi
# hello
#
# hi
# hello

# %%
# 입력받은 정수들을 모두 더한 합을 반환하는 sum_all 함수를 작성하세요

# def sum_all():

# sum_all(1,2,3,4,5)
# sum_all(1,2,3)




def sum_all(*val):
  print(sum(val))

sum_all(1,2,3,4,5)
sum_all(1,2,3)
# Out:
# 15
# 6

# %%
# 기본 매개변수

def print_3(val, n=2):
  for i in range(n):
    print(val)

print_3('hi')
print('----')
print_3('hi',4)
# Out:
# hi
# hi
# ----
# hi
# hi
# hi
# hi

# %%
# 순서를 기본 매개변수를 뒤에 위치시킨다.
def print_3(n=2, val):
  for i in range(n):
    print(val)

print_3('hi')
print('----')
print_3(4,'hi')
# Out:
#   File "<ipython-input-17-fb3407a594bd>", line 1
#     def print_3(n=2, val):
#                ^
# SyntaxError: non-default argument follows default argument

# %%
def print_n_times(n, *args):     #관용적으로 가변매개변수의 이름은 args를 사용한다
  for i in range(n):
    for arg in args:
      print(arg)
    print()

print_n_times(3,'hi','hello','good morning')
print_n_times(3,'hi','hello')
# Out:
# hi
# hello
# good morning
#
# hi
# hello
# good morning
#
# hi
# hello
# good morning
#
# hi
# hello
#
# hi
# hello
#
# hi
# hello

# %%
def test(a, b=10, c=100):
  print(a+b+c)

# 1 기본형태
test(10,20,30)

# 2 모든 매개변수 지정
test(a=10,b=20,c=30)

#3 순서를 섞어서 지정
test(c=30,a=10,b=20)

#4 일부만 지정
test(10,c=30)
# Out:
# 60
# 60
# 60
# 50

# %%
def return_test():
  print('A위치입니다.')
  return                      #return을 만나면 끝이다.
  print('B위치입니다.')

return_test()
# Out:
# A위치입니다.

# %%
def return_test():
  return 100

return_test()
# Out:
# 100

# %%
def sum_all(start, end):
  output = 0
  for i in range(start, end+1):
    output += i

  return output
  
print('0에서 100까지의 합 :', sum_all(0,100))
print('0에서 100까지의 합 :', sum_all(0,1000))
print('0에서 100까지의 합 :', sum_all(50,100))
print('0에서 100까지의 합 :', sum_all(500,1000))
# Out:
# 0에서 100까지의 합 : 5050
# 0에서 100까지의 합 : 500500
# 0에서 100까지의 합 : 3825
# 0에서 100까지의 합 : 375750

# %%
# 재귀 함수   ( 이쁜 쓰레기, 고로 쓰지마라)

def hello():
  print('hi')
  return hello()

  hello()

# %%
# 반복문으로 팩토리얼 구하기

# 함수선언
def facto(n):
  #변수선언
  output = 1
  #반복문을 곱학
  for i in range(1, n+1):
    output*=i
  return output

print('3! : ', facto(3))
print('3! : ', facto(5))
print('3! : ', facto(7))
# Out:
# 3! :  6
# 3! :  120
# 3! :  5040

# %%
# 재귀(recursion)로 팩토리얼 구하기

def facto(n):
  if n == 0:
    return 1
  else:
    return n*facto(n-1)


print('3! : ', facto(3))
print('3! : ', facto(5))
print('3! : ', facto(7))

# 개발자들 사이에서는 재귀함수를 절대 사용하지 말자라는 의견도 있다.
# 하지만 가독성이 좋고 코드가 간결하고 멋스러워 보이는 장점도 있다. (예쁜 쓰레기)

# %%
# 피보나치 수열( 토끼의 번식 속도, 바이러스 감염 속도...)

def fibo(n):
  if n == 1 or n == 2 :
    return 1
  else :
    return fibo(n-1) + fibo(n-2)


print('fibonacci(1) :', fibo(1))
print('fibonacci(2) :', fibo(2))
print('fibonacci(3) :', fibo(3))
print('fibonacci(4) :', fibo(4))
print('fibonacci(5) :', fibo(5))
# Out:
# fibonacci(1) : 1
# fibonacci(2) : 1
# fibonacci(3) : 2
# fibonacci(4) : 3
# fibonacci(5) : 5

# %%
# 튜플과 함수
# 튜플은 함수의 리턴에 많이 사용된다. 함수의 리턴에 튜플을 사용하게 되면 여러 개의 값을 리턴하고 할당할 수 있기 때문이다.

def test():
  return 10,20 # 튜플의 소괄호는 생략도 가능하다.

a,b = test()

print(a)
print(b)

# %%
def add (a,b): # 그 인수를 담아서 함수에서 사용되는 매개변수
  return a+b

a = 3 # 함수로 들어가는 실제 값을 인수 arguments
b = 4

c = add(a,b)
print(c)

# 인수와 매개변수 - 
# 함수와 매서드 - 클래스 안에서 선언한 함수를 매서드라고 부른다
# 객체와 인스턴스 -

# %%
# 함수의 종류 4가지

input도 있고 output도 있는 함수 (*****)
input은 없고 output은 있는 함수
input은 있고 output은 없는 함수
input도 없고 output도 없는 함수

# %%
#1 input도 있고 output도 있는 함수 (*****)

def add (a,b):
  return a+b

print(add(1,2))
# Out:
# 3

# %%
#2 input은 없고 output은 있는 함수

def say ():
  return 'hi'

print(say())
# Out:
# hi

# %%
#3 input은 있고 output은 없는 함수

def add(a,b):
  print('%d,%d의 합은 %d입니다.' %(a,b,a+b))

add(3,4)
# Out:
# 3,4의 합은 7입니다.

# %%
#4 input도 없고 output도 없는 함수

def say():
  print('hi')
  print('hi')
  print('hi')
  print('hi')

say()
# Out:
# hi
# hi
# hi
# hi

# %%
def add(a,b):
  return a+base

print(add(a=3, b=7))
# Out:
# 5

# %%
def add_many(*args):
  result = 0

  for arg in args:
    result += arg
  return result


print(add_many(1,2,3))
print(add_many(1,2,3,4,5))
# Out:
# 6
# 15

# %%
def addd_mul(choice, *args):
  if choice == 'add':
    result = 0
    for i in args :
      result += i
  elif choice == 'mul':
    result = 1
    for i in args:
      result = result * 1
  return result
  

  print('add',1,2,3,4,5)

  print('mul',1,2,3)

# %%
# 함수의 결과는 언제나 하나다 

def add_and_mul(a,b):
  return a+b
  return a*b

result = add_and_mul(3,4)
print(result)
# Out:
# 7

# %%
# 초기값 설정 매개변수는 항상 끝에 위치한다


def say_myself(name,old, man = True, old):
  print('나의 이름은 %s입니다', % name)
  print(f'나의 이름은 {name}입니다.')

  print('나는 %d살입니다', % old)
  print(f'나는 {old}입니다.')

  if man :
    print('남자입니다')
  else:
    print('여자입니다')

say_myself('박응용',27)
say_myself('박응용', 27, True)
say_myself('박응용', 27, false)
# Out:
#   File "<ipython-input-52-5e61dfa2e64e>", line 5
#     print('나의 이름은 %s입니다', % name)
#                           ^
# SyntaxError: invalid syntax

# %%
# 지역변수 local variable와 전역변수 golbal variable

a = 1

def vartest(a):
  a = a+1

vartest(a)
print(a)
# Out:
# 1

# %%
a = 1

def vartest(a):
  a = a+1
  return a

print(vartest(a))
# Out:
# 2

# %%
a = 1

def vartest():
  global a # 전역변수 선언     # 전역변수도 이쁜쓰레기라 쓰지마라!!!
  a = a+1

vartest()
print(a)

# %%
# def add(a,b):
#   return a+b               #위랑 아래코드는 같다


# lambda를 사용하면 코드를 더 깔끔하게 작성할 수 있고, 코드의 복잡성을 줄여준다.
# 반면 재 사용성이 상당히 떨어진다.


add = lambda a,b: a+b     # lambda는 return이 없어도 결과값을 돌려준다.

print(add(3,4))
