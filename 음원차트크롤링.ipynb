# %% [markdown]
# <a href="https://colab.research.google.com/github/10KimJunGu/ai/blob/main/%EC%9D%8C%EC%9B%90%EC%B0%A8%ED%8A%B8%ED%81%AC%EB%A1%A4%EB%A7%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 벅스 멜론 지니 네이버영화

import requests                                 # 파이썬으로 웹페이지 연결
from bs4 import BeautifulSoup as bs            # 분석을 용이하게 정제 (필수)
import pandas                                   # 데이터 분석 (엑셀로 저장, 데이터프레임)
# Out:
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
response = requests.get('http://www.naver.com/')

print(f'응답코드 : {response.status_code}')       # code 200 성공
# Out:
# 응답코드 : 200

# %%
print(response.text)
# Out:
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 
# ...

# %%
response = requests.get('https://music.bugs.co.kr/chart')
response.text
# Out:
# '<!DOCTYPE html>\r\n<html lang="ko">\r\n<head>\r\n\t<!-- bgsweb-www905 -->\r\n\t<meta charset="utf-8">\r\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n\t<meta name="keywords" content="음악,음악 스트리밍,최신음악,인기가요,뮤직비디오,앨범,플레이어,mp3 다운로드,놀면뭐하니,유플래쉬,유플래시" />\r\n\r\n<script type="text/javascript">\r\n\tif(!(location.href.indexOf("music.bugs.co.kr/newPlayer") >= 0 || location.href.indexOf("music.bugs.co.kr/newRadio") >= 0 || location.href.indexOf("localhost") >= 0))\r\n\t\tdocument.domain = \'bugs.co.kr\';\r\n\r\n\tvar g_urlBase = "https://www.bugs.co.kr";\r\n\tvar g_urlWww = "https://www.bugs.co.kr";\r\n\tvar g_urlSecure = "https://secure.bugs.co.kr";\r\n\tvar g_urlMusic = "https://music.bugs.co.kr";\r\n\tvar g_urlMusicSecure = "https://music.bugs.co.kr";\r\n\tvar g_urlMember = "https://secure.bugs.co.kr/member";\r\n\tvar g_urlFile = "https://file.bugsm.co.kr/wbugs";\r\n\tvar g_urlFile_n ="https://file.bugsm.co.kr/nbugs"; \r\n\t//var g_urlSwf = "https://music.bugs.co.kr/swf";\r\n\t
# ...

# %%
soup = bs(response.text)         # 보기가 힘들기 때문에 soup = bs()로 정제
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <!-- bgsweb-www905 -->
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="음악,음악 스트리밍,최신음악,인기가요,뮤직비디오,앨범,플레이어,mp3 다운로드,놀면뭐하니,유플래쉬,유플래시" name="keywords"/>
# <script type="text/javascript">
# 	if(!(location.href.indexOf("music.bugs.co.kr/newPlayer") >= 0 || location.href.indexOf("music.bugs.co.kr/newRadio") >= 0 || location.href.indexOf("localhost") >= 0))
# 		document.domain = 'bugs.co.kr';
#
# 	var g_urlBase = "https://www.bugs.co.kr";
# 	var g_urlWww = "https://www.bugs.co.kr";
# 	var g_urlSecure = "https://secure.bugs.co.kr";
# 	var g_urlMusic = "https://music.bugs.co.kr";
# 	var g_urlMusicSecure = "https://music.bugs.co.kr";
# 	var g_urlMember = "https://secure.bugs.co.kr/member";
# 	var g_urlFile = "https://file.bugsm.co.kr/wbugs";
# 	var g_urlFile_n ="https://file.bugsm.co.kr/nbugs";
# 	//var g_urlSwf = "https://music.bugs.co.kr/swf";
# 	var g_urlSwf = "https://music.bugs.co.kr/swf";
# ...

# %%
len(soup.select('tr'))
# Out:
# 104

# %%
len(soup.select('tbody > tr'))
# Out:
# 103

# %%
len(soup.select('table > tbody > tr'))
# Out:
# 103

# %%
len(soup.select('table.byChart > tbody > tr'))         # table뒤에 . 점 이것은 class를 뜻한다
# Out:
# 100

# %%
songs = soup.select('table.byChart > tbody > tr')

# %%
song = songs[0]

# %%
len(song.select('p'))
# Out:
# 3

# %%
song.select('p.artist > a')
# Out:
# [<a href="https://music.bugs.co.kr/artist/20158908?wl_ref=list_tr_10_chart" onclick="
#  " title="LE SSERAFIM (르세라핌)">LE SSERAFIM (르세라핌)</a>]

# %%
song.select('p.artist > a')[0].text
# Out:
# 'LE SSERAFIM (르세라핌)'

# %%
song.select('p.title > a')
# Out:
# [<a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6160273',true);
#  " title="FEARLESS">FEARLESS</a>]

# %%
song.select('p.title > a')[0].text
# Out:
# 'FEARLESS'

# %%
import pandas as pd

# %%
song_data = []
rank = 1

songs = soup.select('table.byChart > tbody > tr')

for song in songs:
  title = song.select('p.title > a')[0].text
  singer = song.select('p.artist > a')[0].text
  song_data.append(['Bugs', rank, title, singer])
  rank += 1

df = pd.DataFrame(song_data, columns = ['차트명','순위','타이틀','가수'])
df
# Out:
#      차트명   순위                                                타이틀  \
# 0   Bugs    1                                           FEARLESS
# 1   Bugs    2              That That (prod. & feat. SUGA of BTS)
# 2   Bugs    3                                               내 곁에
# 3   Bugs    4                                          LOVE DIVE
# 4   Bugs    5                                             TOMBOY
# ..   ...  ...                                                ...
# 95  Bugs   96  Vegas (From the Original Motion Picture Soundt...
# 96  Bugs   97             회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)
# 97  Bugs   98                    환상동화 (Secret Story of the Swan)
# 98  Bugs   99                                          내 목소리 들리니
# 99  Bugs  100                                Permission to Dance
#
#                     가수
# 0   LE SSERAFIM (르세라핌)
# 1             싸이 (PSY)
# 2         태연 (TAEYEON)
# 3            IVE (아이브)
# 4              (여자)아이들
# ..                 ...
# ...

# %%
#####################################################################################################

# %%
response = requests.get('https://www.melon.com/chart/index.htm')
response.text
# Out:
# ''

# %%
response = requests.get('https://genie.co.kr/chart/top200')
response.text
# Out:
# '<br>\r\n<br>\r\n<center>\r\n<img src="http://www.geniemusic.co.kr/images/common/logo_r1.png"><br>\r\n<h2> <meta http-equiv="Content-Type" content="text/html;charset=UTF-8"> ì\xa0\x91ì\x86\x8dì\x9a\x94ì²\xadì\x9d´ ë³´ì\x95\x88ì\xa0\x95ì±\x85ì\x97\x90 ì\x9d\x98í\x95´ ì°¨ë\x8b¨ë\x90\x98ì\x97\x88ì\x8aµë\x8b\x88ë\x8b¤. ë\x8b¹ì\x82¬ ê³\xa0ê°\x9dì\x84¼í\x84°ë¡\x9c ë¬¸ì\x9d\x98í\x95´ì£¼ì\x8b\xadì\x8b\x9cì\x98¤.<br><br>\r\nThe security policy of the connection request is blocked. Contact your customer service representative.<br><br>\r\nì§\x80ë\x8b\x88ë®¤ì§\x81 ê³\xa0ê°\x9dì\x84¼í\x84° 1577-5337<br><br>\r\n</h2>\r\n</center>\r\n<br>'

# %%
# 코랩에서 셀레니움 사용 방법

# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium

from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:9 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Reading package lists... Done
# ...

# %%
driver = webdriver.Chrome('chromedriver', options=options)
driver.get('https://www.melon.com/chart/index.htm')

# %%
html = driver.page_source
soup = bs(html)

# %%
len(soup.select('tr'))
# Out:
# 101

# %%
len(soup.select('tbody > tr'))
# Out:
# 100

# %%
songs = soup.select('tbody > tr')
song = songs[0]

# %%
song.select('div.rank01 > span > a')
# Out:
# [<a href="javascript:melon.play.playSong('1000002721',34997078);" title="That That (prod. &amp; feat. SUGA of BTS) 재생">That That (prod. &amp; feat. SUGA of BTS)</a>]

# %%
song.select('div.rank01 > span > a')[0].text
# Out:
# 'That That (prod. & feat. SUGA of BTS)'

# %%
song.select('div.rank02 > span > a')[0].text
# Out:
# '싸이 (PSY)'

# %%
song_data = []
rank = 1

songs = soup.select('tbody > tr')

for song in songs:
  title = song.select('div.rank01 > span > a')[0].text
  singer = song.select('div.rank02 > span > a')[0].text
  song_data.append(['Melon', rank, title, singer])
  rank += 1

df = pd.DataFrame(song_data, columns = ['차트명','순위','타이틀','가수'])

df.to_excel('melon.xlsx', index=False)

# %%
##################################################################################################

# %%
driver = webdriver.Chrome('chromedriver', options=options)
driver.get('https://genie.co.kr/chart/top200?ditc=D&ymd=20220509&hh=10&rtm=Y&pg=1')

html = driver.page_source
soup = bs(html)

# %%
len(soup.select('tr.list'))
# Out:
# 50

# %%
songs = soup.select('tr.list')
song = songs[0]

# %%
song.select('a')
# Out:
# [<a class="cover" href="#" onclick="fnViewAlbumLayer('82662688');return false;"><span class="mask"></span><img alt="싸다9" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/662/688/82662688_1651196114166_1_140x140.JPG/dims/resize/Q_80,0"/></a>,
#  <a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('96664100');return false;">곡 제목 정보 페이지</a>,
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('96664100','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  That That (Prod. &amp; Feat. SUGA of BTS)</a>,
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14945898');return false;">싸이 (Psy)</a>,
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82662688');return false;">싸다9</a>,
#  <a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('96664100;' ,'1'); return false;" title="재생">듣기</a>,
# ...

# %%
song.select('a.artist.ellipsis')
# Out:
# [<a class="artist ellipsis" href="#" onclick="fnViewArtist('14945898');return false;">싸이 (Psy)</a>]

# %%
song.select('a.artist.ellipsis')[0].text.strip()
# Out:
# '싸이 (Psy)'

# %%
song.select('a.title.ellipsis')
# Out:
# [<a class="title ellipsis" href="#" onclick="fnPlaySong('96664100','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  That That (Prod. &amp; Feat. SUGA of BTS)</a>]

# %%
song.select('td.info > a.title.ellipsis')[0].text.strip()
# Out:
# 'That That (Prod. & Feat. SUGA of BTS)'

# %%
song_data = []
rank = 1

driver = webdriver.Chrome('chromedriver', options=options)
driver.get('https://genie.co.kr/chart/top200?ditc=D&ymd=20220509&hh=10&rtm=Y&pg=1')

html = driver.page_source
soup = bs(html)


songs = soup.select('tr.list')

for song in songs:
  title = song.select('td.info > a.title.ellipsis')[0].text.strip()
  singer = song.select('a.artist.ellipsis')[0].text.strip()
  song_data.append(['Ginie',rank, title, singer])
  rank += 1






driver = webdriver.Chrome('chromedriver', options=options)
driver.get('https://genie.co.kr/chart/top200?ditc=D&ymd=20220509&hh=10&rtm=Y&pg=2')

html = driver.page_source
soup = bs(html)


songs = soup.select('tr.list')

for song in songs:
  title = song.select('td.info > a.title.ellipsis')[0].text.strip()
  singer = song.select('a.artist.ellipsis')[0].text.strip()
  song_data.append(['Ginie',rank, title, singer])
  rank += 1

df = pd.DataFrame(song_data, columns = ['차트명','순위','타이틀','가수'])

df.to_excel('Ginie.xlsx', index=False)

# %%
###############################################################################
# 네이버 영화 크롤링

import requests                        # 파이썬으로 웹페이지 연결
from bs4 import BeautifulSoup as bs    # 분석을 용이하게 정제
import pandas                          # 데이터 분석 (엑셀로 저장, 데이터프레임)

response = requests.get('https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&date=20220508')


soup = bs(response.text)

# %%
len(soup.select('tr'))
# Out:
# 46

# %%
len(soup.select('tbody > tr'))
# Out:
# 43

# %%
len(soup.select('table.list_ranking > tbody > tr'))
# Out:
# 43

# %%
len(soup.select('div#old_content > table.list_ranking > tbody > tr'))

# 포함하는 바깥쪽으로 범위를 확장해도 줄이지 못하면 꺼꾸로 안쪽으로 범위를 축소한다.
# Out:
# 43

# %%
len(soup.select('td.title'))
# Out:
# 38

# %%
titles = soup.select('td.title')

# %%
titles[0]
# Out:
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=187320" title="씽2게더">씽2게더</a>
# </div>
# </td>

# %%
titles[0].text
# Out:
# '\n\n씽2게더\n\n'

# %%
titles[0].text.strip()
# Out:
# '씽2게더'

# %%
points = soup.select('td.point')
points[0].text.strip()
# Out:
# '9.39'

# %%
movielist = []
rank = 1

titles = soup.select('td.title')
points = soup.select('td.point')

for each in range(len(soup.select('td.title'))):
  title = titles[each].text.strip()
  point = points[each].text.strip()
  movielist.append(['네이버영화순위', rank, title, point])
  rank += 1

df = pd.DataFrame(movielist, columns = ['출처','순위','제목','평점'])
df
# Out:
#          출처  순위                    제목    평점
# 0   네이버영화순위   1                  씽2게더  9.39
# 1   네이버영화순위   2     극장판 귀멸의 칼날: 무한열차편  9.27
# 2   네이버영화순위   3            극장판 주술회전 0  9.26
# 3   네이버영화순위   4                    벤허  9.23
# 4   네이버영화순위   5                   파수꾼  9.18
# 5   네이버영화순위   6                    코다  9.14
# 6   네이버영화순위   7             와이키키 브라더스  9.11
# 7   네이버영화순위   8                비긴 어게인  9.04
# 8   네이버영화순위   9         개를 훔치는 완벽한 방법  9.00
# 9   네이버영화순위  10               남매의 여름밤  8.95
# 10  네이버영화순위  11                  중경삼림  8.90
# 11  네이버영화순위  12                  화양연화  8.81
# 12  네이버영화순위  13             바닷마을 다이어리  8.73
# 13  네이버영화순위  14                   세자매  8.67
# 14  네이버영화순위  15                    안경  8.64
# 15  네이버영화순위  16                  라라랜드  8.62
# 16  네이버영화순위  17                  공기살인  8.60
# 17  네이버영화순위  18                  아비정전  8.45
# 18  네이버영화순위  19             드라이브 마이 카  8.41
# 19  네이버영화순위  20  신은 죽지 않았다 3: 어둠 속의 빛  8.32
# ...
